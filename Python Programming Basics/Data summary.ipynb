# %%
import pandas as pd
ipl=pd.read_csv("IPL IMB381IPL2013.csv")
ipl.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 0       1   Abdulla, YA    2  ...         2009      50000      50000
# 1       2  Abdur Razzak    2  ...         2008      50000      50000
# 2       3   Agarkar, AB    2  ...         2008     200000     350000
# 3       4     Ashwin, R    1  ...         2011     100000     850000
# 4       5  Badrinath, S    2  ...         2011     100000     800000
#
# [5 rows x 26 columns]

# %%
ipl.tail()
# Out:
#      Sl.NO.   PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 125     126     Yadav, AS    2  ...         2010      50000     750000
# 126     127   Younis Khan    2  ...         2008     225000     225000
# 127     128  Yuvraj Singh    2  ...         2011     400000    1800000
# 128     129   Zaheer Khan    2  ...         2008     200000     450000
# 129     130    Zoysa, DNT    2  ...         2008     100000     110000
#
# [5 rows x 26 columns]

# %%
ipl[10:20]
# Out:
#     Sl.NO.      PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 10      11        Bravo, DJ    2  ...         2011     200000     200000
# 11      12   Chanderpaul, S    3  ...         2008     200000     200000
# 12      13       Chawla, PP    1  ...         2008     125000     400000
# 13      14  de Villiers, AB    2  ...         2008     200000     300000
# 14      15        Dhawan, S    2  ...         2011     100000     300000
# 15      16        Dhoni, MS    2  ...         2008     400000    1500000
# 16      17      Dilshan, TM    2  ...         2008     150000     250000
# 17      18        Dinda, AB    2  ...         2011     100000     375000
# 18      19       Dravid, RS    3  ...         2011     400000     500000
# 19      20      Duminy, J-P    2  ...         2009     300000     300000
#
# [10 rows x 26 columns]

# %%
list(ipl.columns)
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
ipl[10:]
# Out:
#      Sl.NO.      PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 10       11        Bravo, DJ    2  ...         2011     200000     200000
# 11       12   Chanderpaul, S    3  ...         2008     200000     200000
# 12       13       Chawla, PP    1  ...         2008     125000     400000
# 13       14  de Villiers, AB    2  ...         2008     200000     300000
# 14       15        Dhawan, S    2  ...         2011     100000     300000
# ..      ...              ...  ...  ...          ...        ...        ...
# 125     126        Yadav, AS    2  ...         2010      50000     750000
# 126     127      Younis Khan    2  ...         2008     225000     225000
# 127     128     Yuvraj Singh    2  ...         2011     400000    1800000
# 128     129      Zaheer Khan    2  ...         2008     200000     450000
# 129     130       Zoysa, DNT    2  ...         2008     100000     110000
#
# [120 rows x 26 columns]

# %%
ipl[-5:]
# Out:
#      Sl.NO.   PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 125     126     Yadav, AS    2  ...         2010      50000     750000
# 126     127   Younis Khan    2  ...         2008     225000     225000
# 127     128  Yuvraj Singh    2  ...         2011     400000    1800000
# 128     129   Zaheer Khan    2  ...         2008     200000     450000
# 129     130    Zoysa, DNT    2  ...         2008     100000     110000
#
# [5 rows x 26 columns]

# %%
ipl['PLAYER NAME'][:5]
# Out:
# 0     Abdulla, YA
# 1    Abdur Razzak
# 2     Agarkar, AB
# 3       Ashwin, R
# 4    Badrinath, S
# Name: PLAYER NAME, dtype: object

# %%
ipl[['PLAYER NAME','AGE','COUNTRY','SOLD PRICE']].sort_values('SOLD PRICE',ascending = False)[0:10]
# Out:
#        PLAYER NAME  AGE COUNTRY  SOLD PRICE
# 93       Sehwag, V    2     IND     1800000
# 127   Yuvraj Singh    2     IND     1800000
# 50        Kohli, V    1     IND     1800000
# 111  Tendulkar, SR    3     IND     1800000
# 113     Tiwary, SS    1     IND     1600000
# 83   Pietersen, KP    2     ENG     1550000
# 23     Flintoff, A    2     ENG     1550000
# 15       Dhoni, MS    2     IND     1500000
# 108     Symonds, A    3     AUS     1350000
# 110   Taylor, LRPL    2      NZ     1000000

# %%
ipl.iloc[::,5:10]
# Out:
#     PLAYING ROLE  T-RUNS  T-WKTS  ODI-RUNS-S  ODI-SR-B
# 0     Allrounder       0       0           0      0.00
# 1         Bowler     214      18         657     71.41
# 2         Bowler     571      58        1269     80.62
# 3         Bowler     284      31         241     84.56
# 4        Batsman      63       0          79     45.93
# ..           ...     ...     ...         ...       ...
# 125      Batsman       0       0           0      0.00
# 126      Batsman    6398       7        6814     75.78
# 127      Batsman    1775       9        8051     87.58
# 128       Bowler    1114     288         790     73.55
# 129       Bowler     288      64         343     95.81
#
# [130 rows x 5 columns]

# %%
pd.crosstab(ipl['COUNTRY'],ipl['PLAYING ROLE'])
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# COUNTRY
# AUS                    6        9       6          1
# BAN                    0        0       1          0
# ENG                    2        1       0          0
# IND                    7       18      23          5
# NZ                     4        2       0          1
# PAK                    2        2       4          1
# SA                     7        3       4          2
# SL                     4        2       5          1
# WI                     3        2       1          0
# ZIM                    0        0       0          1

# %%
ipl['Premium']= ipl['SOLD PRICE']-ipl['BASE PRICE']
ipl[['PLAYER NAME', 'BASE PRICE', 'SOLD PRICE', 'Premium']][0:10]
# Out:
#      PLAYER NAME  BASE PRICE  SOLD PRICE  Premium
# 0    Abdulla, YA       50000       50000        0
# 1   Abdur Razzak       50000       50000        0
# 2    Agarkar, AB      200000      350000   150000
# 3      Ashwin, R      100000      850000   750000
# 4   Badrinath, S      100000      800000   700000
# 5     Bailey, GJ       50000       50000        0
# 6      Balaji, L      100000      500000   400000
# 7  Bollinger, DE      200000      700000   500000
# 8       Botha, J      200000      950000   750000
# 9    Boucher, MV      200000      450000   250000

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.bar(ipl['PLAYING ROLE'],ipl['SOLD PRICE'])
# Out:
# <BarContainer object of 130 artists>

# %%
sn.barplot(ipl['PLAYING ROLE'],ipl['SOLD PRICE'])
# Out:
# <AxesSubplot:xlabel='PLAYING ROLE', ylabel='SOLD PRICE'>

# %%
plt.hist( ipl['SOLD PRICE'] );

# %%
plt.hist( ipl['SOLD PRICE'], bins = 20 );

# %%
sn.distplot( ipl['SOLD PRICE']);

# %%
box = sn.boxplot(ipl['SOLD PRICE']);

# %%
sn.boxplot(x = 'PLAYING ROLE', y = 'SOLD PRICE', data = ipl);

# %%
ipl.describe()
# Out:
#            Sl.NO.         AGE        T-RUNS  ...  AUCTION YEAR    BASE PRICE  \
# count  130.000000  130.000000    130.000000  ...    130.000000  1.300000e+02
# mean    65.500000    2.092308   2166.715385  ...   2009.092308  1.922308e+05
# std     37.671829    0.576627   3305.646757  ...      1.377821  1.530973e+05
# min      1.000000    1.000000      0.000000  ...   2008.000000  2.000000e+04
# 25%     33.250000    2.000000     25.500000  ...   2008.000000  1.000000e+05
# 50%     65.500000    2.000000    542.500000  ...   2008.000000  2.000000e+05
# 75%     97.750000    2.000000   3002.250000  ...   2011.000000  2.250000e+05
# max    130.000000    3.000000  15470.000000  ...   2011.000000  1.350000e+06
#
#          SOLD PRICE
# count  1.300000e+02
# mean   5.212231e+05
# std    4.068074e+05
# min    2.000000e+04
# 25%    2.250000e+05
# 50%    4.375000e+05
# 75%    7.000000e+05
# max    1.800000e+06
#
# [8 rows x 22 columns]

# %%
ipl.describe(include=['object'])
# Out:
#         PLAYER NAME COUNTRY TEAM PLAYING ROLE
# count           130     130  130          130
# unique          130      10   17            4
# top     Abdulla, YA     IND  CSK       Bowler
# freq              1      53   14           44

# %%
ipl['COUNTRY'].value_counts().to_frame()
# Out:
#      COUNTRY
# IND       53
# AUS       22
# SA        16
# SL        12
# PAK        9
# NZ         7
# WI         6
# ENG        3
# BAN        1
# ZIM        1

# %%
ipl['PLAYING ROLE'].value_counts().to_frame()
# Out:
#             PLAYING ROLE
# Bowler                44
# Batsman               39
# Allrounder            35
# W. Keeper             12

# %%
ipl.mean()
# Out:
# Sl.NO.               65.500000
# AGE                   2.092308
# T-RUNS             2166.715385
# T-WKTS               66.530769
# ODI-RUNS-S         2508.738462
# ODI-SR-B             71.164385
# ODI-WKTS             76.076923
# ODI-SR-BL            34.033846
# CAPTAINCY EXP         0.315385
# RUNS-S              514.246154
# HS                   47.430769
# AVE                  18.719308
# SR-B                111.053462
# SIXERS               17.692308
# RUNS-C              475.523077
# WKTS                 17.169231
# AVE-BL               23.110231
# ECON                  6.204462
# SR-BL                17.382615
# AUCTION YEAR       2009.092308
# BASE PRICE       192230.769231
# SOLD PRICE       521223.076923
# dtype: float64

# %%
ipl.median()
# Out:
# Sl.NO.               65.500
# AGE                   2.000
# T-RUNS              542.500
# T-WKTS                7.000
# ODI-RUNS-S          835.000
# ODI-SR-B             78.225
# ODI-WKTS             18.500
# ODI-SR-BL            36.600
# CAPTAINCY EXP         0.000
# RUNS-S              172.000
# HS                   35.500
# AVE                  18.635
# SR-B                118.510
# SIXERS                6.000
# RUNS-C              297.000
# WKTS                  8.500
# AVE-BL               24.785
# ECON                  7.380
# SR-BL                19.935
# AUCTION YEAR       2008.000
# BASE PRICE       200000.000
# SOLD PRICE       437500.000
# dtype: float64

# %%
#Calculate Maximum value
ipl.max()
# Out:
# Sl.NO.                       130
# PLAYER NAME      de Villiers, AB
# AGE                            3
# COUNTRY                      ZIM
# TEAM                         RR+
# PLAYING ROLE           W. Keeper
# T-RUNS                     15470
# T-WKTS                       800
# ODI-RUNS-S                 18426
# ODI-SR-B                  116.66
# ODI-WKTS                     534
# ODI-SR-BL                  150.0
# CAPTAINCY EXP                  1
# RUNS-S                      2254
# HS                           158
# AVE                        50.11
# SR-B                      235.49
# SIXERS                       129
# RUNS-C                      1975
# WKTS                          83
# AVE-BL                     126.3
# ECON                       38.11
# SR-BL                      100.2
# AUCTION YEAR                2011
# BASE PRICE               1350000
# SOLD PRICE               1800000
# dtype: object

# %%
#Calculate Standard deviation
ipl.std()
# Out:
# Sl.NO.               37.671829
# AGE                   0.576627
# T-RUNS             3305.646757
# T-WKTS              142.676855
# ODI-RUNS-S         3582.205625
# ODI-SR-B             25.898440
# ODI-WKTS            111.205070
# ODI-SR-BL            26.751749
# CAPTAINCY EXP         0.466466
# RUNS-S              615.226335
# HS                   36.403624
# AVE                  11.094224
# SR-B                 35.928907
# SIXERS               23.828146
# RUNS-C              558.314049
# WKTS                 21.816763
# AVE-BL               20.802057
# ECON                  4.941531
# SR-BL                15.273422
# AUCTION YEAR          1.377821
# BASE PRICE       153097.300897
# SOLD PRICE       406807.351419
# dtype: float64

# %%
# calculate Variance
ipl.var()
# Out:
# Sl.NO.           1.419167e+03
# AGE              3.324985e-01
# T-RUNS           1.092730e+07
# T-WKTS           2.035669e+04
# ODI-RUNS-S       1.283220e+07
# ODI-SR-B         6.707292e+02
# ODI-WKTS         1.236657e+04
# ODI-SR-BL        7.156561e+02
# CAPTAINCY EXP    2.175909e-01
# RUNS-S           3.785034e+05
# HS               1.325224e+03
# AVE              1.230818e+02
# SR-B             1.290886e+03
# SIXERS           5.677806e+02
# RUNS-C           3.117146e+05
# WKTS             4.759711e+02
# AVE-BL           4.327256e+02
# ECON             2.441872e+01
# SR-BL            2.332774e+02
# AUCTION YEAR     1.898390e+00
# BASE PRICE       2.343878e+10
# SOLD PRICE       1.654922e+11
# dtype: float64

# %%
# Calculate skewness
ipl.skew()
# Out:
# Sl.NO.           0.000000
# AGE              0.000816
# T-RUNS           1.928024
# T-WKTS           3.104904
# ODI-RUNS-S       1.874177
# ODI-SR-B        -1.438180
# ODI-WKTS         1.797747
# ODI-SR-BL        1.060627
# CAPTAINCY EXP    0.803916
# RUNS-S           1.123952
# HS               0.586836
# AVE              0.147521
# SR-B            -0.589874
# SIXERS           1.889971
# RUNS-C           1.195525
# WKTS             1.376290
# AVE-BL           1.203221
# ECON             1.918096
# SR-BL            1.294332
# AUCTION YEAR     0.590204
# BASE PRICE       4.400709
# SOLD PRICE       1.376956
# dtype: float64

# %%
# Calculate kurtosis
ipl. kurtosis()
# Out:
# Sl.NO.           -1.200000
# AGE              -0.001264
# T-RUNS            3.374525
# T-WKTS           10.233566
# ODI-RUNS-S        3.496939
# ODI-SR-B          1.876015
# ODI-WKTS          2.803627
# ODI-SR-BL         3.527734
# CAPTAINCY EXP    -1.375115
# RUNS-S            0.083080
# HS               -0.611755
# AVE              -0.810452
# SR-B              2.268089
# SIXERS            4.198432
# RUNS-C            0.306187
# WKTS              0.811174
# AVE-BL            3.862908
# ECON             12.597887
# SR-BL             5.503534
# AUCTION YEAR     -1.572372
# BASE PRICE       28.768747
# SOLD PRICE        2.004515
# dtype: float64
